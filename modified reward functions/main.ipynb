# %%
from citylearn import  CityLearn
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
np.random.seed(3)

# %%
# Load environment
data_folder = Path("data/")
building_attributes = data_folder / 'building_attributes.json'
solar_profile = data_folder / 'solar_generation_1kW.csv'
building_state_actions = 'buildings_state_action_space.json'
#building_ids = ["Building_1","Building_2","Building_3","Building_4","Building_5","Building_6","Building_7","Building_8","Building_9"]
building_ids = ["Building_1"]
env = CityLearn(building_attributes, solar_profile, building_ids, buildings_states_actions = building_state_actions, cost_function = ['ramping','1-load_factor','peak_to_valley_ratio','peak_demand','net_electricity_consumption'])
observations_spaces,actions_spaces = env.get_state_action_spaces()
# Out:
# <iterator object at 0x11529f4e0>
# 0
# <bound method CityLearn.next_hour of <citylearn.CityLearn object at 0x115268588>>
# stte nme day
# stte nme hour
# stte nme daylight_savings_status
# stte nme t_out
# stte nme rh_out
# stte nme diffuse_solar_rad
# stte nme direct_solar_rad
# stte nme t_in
# stte nme avg_unmet_setpoint
# stte nme rh_in
# stte nme non_shiftable_load
# stte nme solar_gen
# stte nme cooling_storage_soc
# stte nme dhw_storage_soc

# %%
actions_spaces
# Out:
# [Box(2,)]

# %%
# RL CONTROLLER
from reward_function import reward_function
from agent import TD3_Agents
import time

#Instantiating the control agent(s)
agents = TD3_Agents(observations_spaces,actions_spaces)

k, c = 0, 0
cost, cum_reward = {}, {}

start = time.time()
episodes = 300
for e in range(episodes): #A stopping criterion can be added, which is based on whether the cost has reached some specific threshold or is no longer improving
    cum_reward[e] = 0
    rewards = []
    state = env.reset()
    print(state)
    done = False
    while not done:
        if k%(40000*4)==0:
            print('hour: '+str(k)+' of '+str(8760*episodes))
            
        action = agents.select_action(state)
        print(action)
        next_state, reward, done, _ = env.step(action)
        reward = reward_function(reward) #See comments in reward_function.py
        agents.add_to_buffer(state, action, reward, next_state, done)
        state = next_state
        cum_reward[e] += reward[0]
        rewards.append(reward)
        k+=1
    cost[e] = env.cost()
    if c%20==0:
        print(cost[e])
    c+=1
        
end = time.time()
print((end-start)/60.0)
# Out:
# <iterator object at 0x12c9faf98>
# 0
# <bound method CityLearn.next_hour of <citylearn.CityLearn object at 0x115268588>>
# stte nme day
# stte nme hour
# stte nme daylight_savings_status
# stte nme t_out
# stte nme rh_out
# stte nme diffuse_solar_rad
# stte nme direct_solar_rad
# stte nme t_in
# stte nme avg_unmet_setpoint
# stte nme rh_in
# stte nme non_shiftable_load
# stte nme solar_gen
# stte nme cooling_storage_soc
# stte nme dhw_storage_soc
# [[ 8.        1.        0.       17.8125   68.125     0.        0.
#   23.818544  0.       42.676197  9.27775   0.        0.        0.      ]]
# hour: 0 of 2628000
# [array([-0.07888467,  0.06195369])]
# 1
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.07525087,  0.10046004])]
# 2
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.17674895, 0.21102516])]
# 3
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.07419272,  0.1131218 ])]
# 4
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.01711794, 0.18523171])]
# 5
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.04149871, 0.1446795 ])]
# 6
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.16905657, 0.03477935])]
# 7
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.00200424, -0.25      ])]
# 8
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 9
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.04771775, -0.11922153])]
# 10
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.07572986])]
# 11
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.04186396, -0.00443218])]
# 12
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.00645262])]
# 13
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 14
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 15
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.045936  , 0.06010494])]
# 16
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 17
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.08200103, -0.12765047])]
# 18
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.22864232, -0.1234592 ])]
# 19
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.01111288])]
# 20
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.01284534, -0.0191775 ])]
# 21
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.23883949, -0.03733135])]
# 22
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.05301389, -0.07441403])]
# 23
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.22263466, 0.23420329])]
# 24
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 25
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      ,  0.03653423])]
# 26
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.16545967, -0.04237637])]
# 27
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.12594856, -0.22262777])]
# 28
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.04051283, -0.25      ])]
# 29
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.01939321, -0.02105762])]
# 30
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.10345227, 0.21060809])]
# 31
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.13543282, -0.0473826 ])]
# 32
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.20585233])]
# 33
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.09569659, 0.25      ])]
# 34
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.23701911])]
# 35
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 36
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.19533502])]
# 37
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.18065066])]
# 38
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.11163807])]
# 39
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.08349956, 0.19205368])]
# 40
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.00357855])]
# 41
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.00215498, 0.15555201])]
# 42
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.05409071, -0.17377031])]
# 43
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.17242498,  0.09895148])]
# 44
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.2118809 , -0.15900856])]
# 45
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.10700794, -0.10488978])]
# 46
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.02364017, 0.25      ])]
# 47
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.20574063,  0.01122458])]
# 48
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.22745047, -0.10027631])]
# 49
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.09019069])]
# 50
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.02060512, 0.22103372])]
# 51
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.24026895, -0.08732643])]
# 52
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.24818672, 0.16684599])]
# 53
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.06949598, -0.25      ])]
# 54
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.00338466, -0.09962017])]
# 55
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.09669872, 0.18124206])]
# 56
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.20907075])]
# 57
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.07791808])]
# 58
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 59
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.15593325])]
# 60
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25,  0.25])]
# 61
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.091311 , -0.0609499])]
# 62
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.16769577])]
# 63
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 64
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.07417437, 0.1228925 ])]
# 65
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.24780832])]
# 66
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.07707174, 0.07582806])]
# 67
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.16599481, 0.22792741])]
# 68
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.0293124 ,  0.15542674])]
# 69
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.18556379, -0.25      ])]
# 70
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.06909299, -0.25      ])]
# 71
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.16069337,  0.25      ])]
# 72
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.14311885, -0.12024146])]
# 73
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.03495158, -0.21082499])]
# 74
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.02031512])]
# 75
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.02658609,  0.02144321])]
# 76
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.15116111, 0.16682586])]
# 77
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.06327661, -0.15697068])]
# 78
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.2277501,  0.25     ])]
# 79
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.10949711,  0.21164931])]
# 80
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.10120227])]
# 81
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25     , 0.1614354])]
# 82
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25     , 0.1121155])]
# 83
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.18376102, 0.23648242])]
# 84
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.06127497, 0.01595857])]
# 85
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 86
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.01805912])]
# 87
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.06068969])]
# 88
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.06831559, -0.23807739])]
# 89
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.09941717])]
# 90
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.10613787, -0.09118733])]
# 91
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.00663583, -0.25      ])]
# 92
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.20259417, -0.25      ])]
# 93
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.05299621,  0.10676235])]
# 94
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.01304776, 0.23899633])]
# 95
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.03299875, -0.16419978])]
# 96
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.12724644, -0.10630124])]
# 97
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25     , 0.0514159])]
# 98
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.23233699])]
# 99
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.19324793, -0.17887637])]
# 100
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.14531333, -0.0733688 ])]
# 101
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.169445  ,  0.12331514])]
# 102
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.11373584, 0.25      ])]
# 103
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.20639199, 0.25      ])]
# 104
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 105
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.179135, 0.25    ])]
# 106
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.23837822])]
# 107
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.21023299])]
# 108
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.1224252 , 0.07717312])]
# 109
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.06550312,  0.08849573])]
# 110
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 111
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.18770014, 0.25      ])]
# 112
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 113
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.10841398, 0.00123254])]
# 114
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.11341766])]
# 115
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.04003267, 0.22607642])]
# 116
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.10070268, -0.12467363])]
# 117
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.10403693,  0.10713221])]
# 118
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.04327142,  0.10812176])]
# 119
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.09972246, 0.21662672])]
# 120
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.15648523, -0.06625737])]
# 121
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.03727315,  0.25      ])]
# 122
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.19452427, -0.0219769 ])]
# 123
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.25      , -0.15351829])]
# 124
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25      , 0.17632392])]
# 125
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.08668901, 0.2260132 ])]
# 126
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.1684272 , -0.09212871])]
# 127
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25, 0.25])]
# 128
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.25     , 0.1023647])]
# 129
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.18538209, 0.18414272])]
# 130
# state_name day
# state_name hour
# state_name daylight_savings_status
# ...
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1910
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1911
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.18963125, -0.25      ])]
# 1912
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1913
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.03558111])]
# 1914
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1915
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.140502, -0.25    ])]
# 1916
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.00710386, -0.25      ])]
# 1917
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.16576465])]
# 1918
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.00130102, -0.03005409])]
# 1919
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.02633765, -0.142625  ])]
# 1920
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1921
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1922
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.14274581])]
# 1923
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1924
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.1516014, -0.25     ])]
# 1925
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.12299824, -0.20668503])]
# 1926
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.24324611])]
# 1927
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1928
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1929
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.22004956, -0.12390157])]
# 1930
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.15945486])]
# 1931
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.14714274, -0.25      ])]
# 1932
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([0.07510865, 0.00622729])]
# 1933
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.18441189, -0.01532602])]
# 1934
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1935
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1936
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.01235468, -0.16581933])]
# 1937
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25, -0.25])]
# 1938
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.16438705,  0.03125875])]
# 1939
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.13970023, -0.25      ])]
# 1940
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.21793685])]
# 1941
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.19438694])]
# 1942
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      ,  0.00079118])]
# 1943
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      ,  0.01865641])]
# 1944
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.25      , -0.17895816])]
# 1945
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([ 0.24042326, -0.13434485])]
# 1946
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.23114467, -0.09306429])]
# 1947
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# [array([-0.23625455, -0.25      ])]
# 1948
# state_name day
# state_name hour
# state_name daylight_savings_status
# state_name t_out
# state_name rh_out
# state_name diffuse_solar_rad
# state_name direct_solar_rad
# state_name t_in
# state_name avg_unmet_setpoint
# state_name rh_in
# state_name non_shiftable_load
# state_name solar_gen
# state_name cooling_storage_soc
# state_name dhw_storage_soc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-161097a1f855> in <module>
#      26         next_state, reward, done, _ = env.step(action)
#      27         reward = reward_function(reward) #See comments in reward_function.py
# ---> 28         agents.add_to_buffer(state, action, reward, next_state, done)
#      29         state = next_state
#      30         cum_reward[e] += reward[0]
#
# ~/Documents/harshita/Academics/semester3/citylearn new/CityLearn-master/agent.py in add_to_buffer(self, states, actions, rewards, next_states, dones)
#     189                     # Optimize the critic
#     190                     self.critic_optimizer[i].zero_grad()
# --> 191                     critic_loss.backward()
#     192                     self.critic_optimizer[i].step()
#     193
#
# /anaconda3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# /anaconda3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
#Prints the cost of every episode. The lower the better. Ideally it will reach the same cost or lower than the RBC: 156.88
cost

# %%
#Prints the actor and critic losses
fig, (plot1, plot2, plot3) = plt.subplots(1,3)
fig.set_size_inches(12,4)
plot1.plot(agents.critic1_loss_list[0],'b')
plot2.plot(agents.critic2_loss_list[0],'g')
plot3.plot(agents.actor_loss_list[0],'y')
plot1.set_xlabel('hours*iterations')
plot1.set_ylabel('Critic 1 loss')
plot2.set_xlabel('hours*iterations')
plot2.set_ylabel('Critic 2 loss')
plot3.set_xlabel('hours*iterations')
plot3.set_ylabel('Actor loss')

# %%
#Plots for the last 100 hours of the simulation
plt.plot(env.buildings[0].cooling_device.electrical_consumption_cooling[2400:])
plt.plot(env.buildings[0].sim_results['cooling_demand'][3500:6000].values[2400:])
plt.plot(env.buildings[0].cooling_device.cooling_supply[2400:])
plt.legend(['Electrical consumption cooling','Building cooling demand','Heat pump cooling supply'])

# %%
interval = range(0,8759)
plt.figure(figsize=(18,8))
plt.plot(env.net_electric_consumption[interval]+env.electric_generation[interval]-env.electric_consumption_cooling_storage[interval]-env.electric_consumption_dhw_storage[interval])
plt.plot(env.net_electric_consumption[interval]-env.electric_consumption_cooling_storage[interval]-env.electric_consumption_dhw_storage[interval])
plt.plot(env.net_electric_consumption[interval], '--')
plt.legend(['Electricity demand without storage or generation (kW)', 'Electricity demand with PV generation and without storage(kW)', 'Electricity demand using RBC for storage(kW)'])
